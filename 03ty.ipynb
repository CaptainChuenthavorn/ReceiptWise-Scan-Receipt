# %%
import pytesseract
from PIL import Image

# %%
img_file = "data/page_01.jpg"
no_noise = r"binarize_temp\bw_image_kbank_1.jpg"

# %%
img = Image.open(no_noise)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1074x1368>

# %%
ocr_result =  pytesseract.image_to_string(img, lang='tha+eng')

# %%
print (ocr_result)
# Out:
# จ่ายบิลสําเร็จ                                 | 4+
# 28 n.A. 66 14:58 น.
#
# นาย จักรภัทรณ์ ช
# ธ.ภสิกรไทย
#
# XXX-X-X426 7-X
#
# เอ็มเอ็กซ์ แจแปนนิส Wa
#
# N
#      MEGABANGNA
#
# OR
# เลขที่รายการ:
# 013209145826CPM04076
# จํานวน:
# 810.00 บาท
# ค่าธรรมเนียม:
# 0.00 บาท      สแกนตรวจสอบสลิป
#
# บันทึกช่วยจํา: เนื้อย่าง
